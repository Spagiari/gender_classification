# %% [markdown]
# <a href="https://colab.research.google.com/github/Spagiari/gender_classification/blob/master/gender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

# %%
df = pd.read_json ('https://raw.githubusercontent.com/Spagiari/gender_classification/master/gender_base.json')

# %%
df.head()
# Out:
#         name sex
# 0   DOMITILA   F
# 1      LIRIO   M
# 2       RUMI   F
# 3      AHMED   M
# 4  GLEYCIANE   F

# %%
df.size
# Out:
# 19926

# %%
df[df.sex == 'F'].size
# Out:
# 14020

# %%
df[df.sex == 'M'].size
# Out:
# 5906

# %%
df_names = df

# %%
df_names.sex.replace({'F': 0, 'M': 1}, inplace=True)

# %%
df_names.head()
# Out:
#         name  sex
# 0   DOMITILA    0
# 1      LIRIO    1
# 2       RUMI    0
# 3      AHMED    1
# 4  GLEYCIANE    0

# %%
df_names.sex.unique()
# Out:
# array([0, 1])

# %%
Xfeatures = df_names['name']

# %%
cv = CountVectorizer()
X = cv.fit_transform(Xfeatures)

# %%
cv.get_feature_names()
# Out:
# ['aaron',
#  'abadia',
#  'abdala',
#  'abdalla',
#  'abdel',
#  'abdias',
#  'abdo',
#  'abdon',
#  'abel',
#  'abelardo',
#  'abgail',
#  'abia',
#  'abigail',
#  'abilio',
#  'abimael',
#  'abmael',
#  'abner',
#  'abraao',
#  'abraham',
#  'abrahao',
#  'abrao',
#  'acacia',
#  'acacio',
#  'acassia',
#  'acassio',
#  'acelino',
#  'achiles',
#  'acir',
#  'acrisio',
#  'acsa',
#  'acy',
#  'acyr',
#  'ada',
#  'adaiane',
#  'adail',
#  'adailson',
#  'adailton',
#  'adailza',
#  'adair',
#  'adalberto',
#  'adalgisa',
#  'adalgiza',
#  'adalia',
#  'adalice',
#  'adalto',
#  'adalton',
#  'adalzira',
#  'adam',
#  'adamo',
#  'adan',
#  'adao',
#  'adauto',
#  'adda',
#  'adeilda',
#  'adeildo',
#  'adeilson',
#  'adeilton',
#  'adeilza',
#  'adel',
#  'adela',
#  'adelaide',
#  'adelaine',
#  'adelana',
#  'adelar',
#  'adelcio',
#  'adele',
#  'adelfo',
#  'adeli',
#  'adelia',
#  'adeliane',
#  'adelice',
#  'adelina',
#  'adeline',
#  'adelino',
#  'adelio',
#  'adelir',
# ...

# %%
y = df_names.sex

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.50)

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(X, y)
clf.score(X_test, y_test)
# Out:
# 1.0

# %%
# 0 -- FEMININO // 1 - MASCULINO
sample_name = ['MERLOTO']
vect = cv.transform(sample_name).toarray()
clf.predict(vect)
# Out:
# array([0])
